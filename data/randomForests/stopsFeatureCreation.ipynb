# %%
import pandas as pd
import datetime as dt
from matplotlib import pyplot as plt

# %% [markdown]
# ## Read cleaned csv

# %%
df = pd.read_csv('combinedDF_MODELING_1.csv')

# %% [markdown]
# ### Make sure the features are the correct datatypes

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  PROGRNUMBER  \
# 0         2018-01-01  5955344    25B  25B_271          2           33
# 1         2018-01-01  5955346    25B  25B_271          2           33
# 2         2018-01-01  5955349    25A  25A_270          2           33
# 3         2018-01-01  5955351    25A  25A_270          2           33
# 4         2018-01-01  5955353    25A  25A_270          2           33
# ...              ...      ...    ...      ...        ...          ...
# 7228363   2018-12-31  8591706     27    27_17          2           63
# 7228364   2018-12-31  8591908     15    15_17          2           52
# 7228365   2018-12-31  8591910     15    15_17          2           52
# 7228366   2018-12-31  8591912     15    15_17          2           52
# 7228367   2018-12-31  8591914     15    15_17          2           52
#
#          startStop  ARR/DEP_PLAN  ARR_ACT  DEP_ACT  endStop  JOURNEYTIME
# 0             1478         37184    37186    37210   1479.0         54.0
# 1             1478         44934    44653    44653   1479.0         21.0
# 2             1478         71051    70983    70983   1479.0         29.0
# 3             1478         77408    77399    77399   1479.0         29.0
# 4             1478         84608    84562    84562   1479.0         21.0
# ...            ...           ...      ...      ...      ...          ...
# 7228363        672         60037    60317    60328   4382.0         45.0
# 7228364        672         32013    32487    32487   4382.0         16.0
# 7228365        672         46010    45188    45210   4382.0         44.0
# 7228366        672         58897    58718    58718   4382.0         21.0
# 7228367        672         71632    71524    71532   4382.0         32.0
#
# [7228368 rows x 12 columns]

# %%
df['DAYOFSERVICE'] = pd.to_datetime(df['DAYOFSERVICE'])

# %%
# month
df['MONTH'] = df['DAYOFSERVICE'].dt.month

# %%
# Day of the week
df['WEEKDAY'] = df['DAYOFSERVICE'].dt.weekday

# %%
# hour
df['HOUR'] = (df['ARR/DEP_PLAN']//60)//60

# %% [markdown]
# ### Sort dataframe

# %%
df.sort_values(by=['DAYOFSERVICE', 'TRIPID', 'LINEID', 'startStop', 'endStop'], inplace=True, ignore_index=True)

# %% [markdown]
# ## Check for negative journey times

# %%
df[(df['JOURNEYTIME']<0)]
# Out:
#         DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  PROGRNUMBER  \
# 198706    2018-01-10  6103556    27A    27A_5          2           33
# 198708    2018-01-10  6103556    27A    27A_5          2           35
# 262604    2018-01-13  6103433     37    37_15          2           50
# 416278    2018-01-21  6221375    83A   83A_26          2           20
# 425012    2018-01-22  6214297     39    39_21          2           64
# ...              ...      ...    ...      ...        ...          ...
# 7032692   2018-12-19  8468292    145  145_105          2           70
# 7078582   2018-12-21  8469032    15B   15B_60          1           13
# 7123536   2018-12-24  8588235     31    31_18          2           47
# 7192053   2018-12-29  8587352    130   130_11          2           30
# 7210341   2018-12-30  8591148    145  145_105          2           70
#
#          startStop  ARR/DEP_PLAN  ARR_ACT  DEP_ACT  endStop  JOURNEYTIME  \
# 198706         616         78469    78615    78627    617.0        -52.0
# 198708         618         78539    81892    81892    619.0      -3179.0
# 262604        1478         77931    78233    78233   1479.0        -21.0
# 416278        1070         78035    79833    79833   1071.0      -1842.0
# 425012        1478         41840    42439    42439   1479.0        -23.0
# ...            ...           ...      ...      ...      ...          ...
# 7032692       1444         30510    38253    38253   1445.0      -7672.0
# 7078582       1018         56124    69271    69271   1019.0     -12367.0
# 7123536        614         59384    59725    59737    615.0       -398.0
# 7192053        615         55246    55429    55429    616.0       -124.0
# 7210341       1444         32306    39471    39471   1445.0      -7000.0
#
#          MONTH  WEEKDAY  HOUR
# 198706       1        2    21
# 198708       1        2    21
# 262604       1        5    21
# 416278       1        6    21
# 425012       1        0    11
# ...        ...      ...   ...
# 7032692     12        2     8
# 7078582     12        4    15
# 7123536     12        0    16
# 7192053     12        5    15
# 7210341     12        6     8
#
# [139 rows x 15 columns]

# %% [markdown]
# ## If there negative journeytimes, remove them

# %%
# get a list of the dates with the negative journeytimes
neg = list(df[df['JOURNEYTIME']<0].index)

# %%
df.drop(neg, inplace=True)

# %% [markdown]
# ### Final check for negative journey times

# %%
df[df['JOURNEYTIME']<0]
# Out:
# Empty DataFrame
# Columns: [DAYOFSERVICE, TRIPID, LINEID, ROUTEID, DIRECTION, PROGRNUMBER, startStop, ARR/DEP_PLAN, ARR_ACT, DEP_ACT, endStop, JOURNEYTIME, MONTH, WEEKDAY, HOUR]
# Index: []

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Check for null JOURNEYTIMEs

# %%
df[df['JOURNEYTIME'].isna()]
# Out:
# Empty DataFrame
# Columns: [DAYOFSERVICE, TRIPID, LINEID, ROUTEID, DIRECTION, PROGRNUMBER, startStop, ARR/DEP_PLAN, ARR_ACT, DEP_ACT, endStop, JOURNEYTIME, MONTH, WEEKDAY, HOUR]
# Index: []

# %% [markdown]
# ## Remove outliers in terms of journey time

# %%
df
# Out:
#          DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 0          2018-01-01  5955277     16   16_20          1           26
# 1          2018-01-01  5955277     16   16_20          1           28
# 2          2018-01-01  5955277     16   16_20          1           29
# 3          2018-01-01  5955277     16   16_20          1           30
# 4          2018-01-01  5955277     16   16_20          1           31
# ...               ...      ...    ...     ...        ...          ...
# 11510228   2018-12-31  8592110     11   11_42          2           35
# 11510229   2018-12-31  8592114     7A   7A_87          2           59
# 11510230   2018-12-31  8592114     7A   7A_87          2           60
# 11510231   2018-12-31  8592116     7A   7A_87          2           59
# 11510232   2018-12-31  8592116     7A   7A_87          2           60
#
#           startStop  ARR/DEP_PLAN  ARR_ACT  DEP_ACT  endStop  JOURNEYTIME  \
# 0                44         31277    31102    31102     45.0         50.0
# 1                45         31343    31152    31163     46.0         55.0
# 2                46         31407    31207    31239     47.0         74.0
# 3                47         31484    31281    31288     48.0         34.0
# 4                48         31551    31315    31327     49.0         47.0
# ...             ...           ...      ...      ...      ...          ...
# 11510228        907         76743    77123    77123    908.0         14.0
# 11510229        493         47228    47217    47236    494.0         59.0
# 11510230        494         47316    47276    47296    495.0         74.0
# 11510231        493         57610    58257    58273    494.0         67.0
# 11510232        494         57676    58324    58339    495.0        100.0
#
#           MONTH  WEEKDAY  HOUR
# 0             1        0     8
# 1             1        0     8
# 2             1        0     8
# 3             1        0     8
# 4             1        0     8
# ...         ...      ...   ...
# 11510228     12        0    21
# 11510229     12        0    13
# 11510230     12        0    13
# 11510231     12        0    16
# 11510232     12        0    16
#
# [11510233 rows x 15 columns]

# %% [markdown]
# ### remove outliers in terms of the standard deviation

# %%
outliersIndexList = []

for startStop in df['startStop'].unique():
    
    stopDF = df[df['startStop']==startStop]
    
    for endStop in stopDF['endStop'].unique():
        
        workingDF0 = stopDF[stopDF['endStop']==endStop]
        
        upper = (workingDF0['JOURNEYTIME'].mean())+(3*(workingDF0['JOURNEYTIME'].std()))
        lower = (workingDF0['JOURNEYTIME'].mean())-(3*(workingDF0['JOURNEYTIME'].std()))
        
        outliers = workingDF0[(workingDF0['JOURNEYTIME']>upper)|(workingDF0['JOURNEYTIME']<lower)].index
        outliersIndexList.append(outliers)

# %%
OutliersIndexList = []

for i in outliersIndexList:
    for j in i:
        OutliersIndexList.append(j)

# %%
df.drop(df.index[OutliersIndexList], inplace=True)

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#         DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 0         2018-01-01  5955277     16   16_20          1           26
# 1         2018-01-01  5955277     16   16_20          1           28
# 2         2018-01-01  5955277     16   16_20          1           29
# 3         2018-01-01  5955277     16   16_20          1           30
# 4         2018-01-01  5955277     16   16_20          1           31
# ...              ...      ...    ...     ...        ...          ...
# 7158332   2018-12-31  8592110     11   11_42          2           49
# 7158333   2018-12-31  8592110     11   11_42          2           50
# 7158334   2018-12-31  8592110     11   11_42          2           51
# 7158335   2018-12-31  8592114     7A   7A_87          2           61
# 7158336   2018-12-31  8592116     7A   7A_87          2           61
#
#          startStop  ARR/DEP_PLAN  ARR_ACT  DEP_ACT  endStop  JOURNEYTIME  \
# 0               44         31277    31102    31102   7603.0         16.0
# 1               45         31343    31152    31163     46.0         55.0
# 2               46         31407    31207    31239     47.0         74.0
# 3               47         31484    31281    31288     48.0         34.0
# 4               48         31551    31315    31327     49.0         47.0
# ...            ...           ...      ...      ...      ...          ...
# 7158332         17         77964    78738    78748     18.0         46.0
# 7158333         18         78022    78784    78784     19.0         42.0
# 7158334         19         78046    78826    78865     21.0         75.0
# 7158335        495         47426    47350    47368    400.0         54.0
# 7158336        495         57796    58424    58424    400.0         66.0
#
#          MONTH  WEEKDAY  HOUR
# 0            1        0     8
# 1            1        0     8
# 2            1        0     8
# 3            1        0     8
# 4            1        0     8
# ...        ...      ...   ...
# 7158332     12        0    21
# 7158333     12        0    21
# 7158334     12        0    21
# 7158335     12        0    13
# 7158336     12        0    16
#
# [7158337 rows x 15 columns]

# %% [markdown]
# ## Merge with weather dataframe
# - create DAYHOUR to combine two dataframes on

# %%
df['DAYHOUR'] = df['DAYOFSERVICE'] + pd.to_timedelta(df['HOUR'], unit='H')

# %%
weather = pd.read_csv('weatherData_CLEANED.csv')
weather['DAYHOUR'] = pd.to_datetime(weather['DAYHOUR'])

# %% [markdown]
# - drop descriptive weather features

# %%
weather.reset_index(drop=True, inplace=True)

# %%
weather.drop(columns=['weather_main', 'weather_description'], inplace=True)

# %% [markdown]
# - add precipitation feature

# %%
# change nan values to 0 for rain and snow
nullRain = weather.loc[pd.isnull(weather['rain_1h']), 'rain_1h'].index
weather.loc[nullRain, 'rain_1h'] = 0

nullSnow = weather.loc[pd.isnull(weather['snow_1h']), 'snow_1h'].index
weather.loc[nullSnow, 'snow_1h'] = 0

# %%
weather['precipitation_1h'] = ((weather['rain_1h']) + (weather['snow_1h']))

# %%
weather.drop(columns=['rain_1h', 'snow_1h'], inplace=True)

# %% [markdown]
# ### Change precipitation values that are NaN to 0

# %%
df = pd.merge(df, weather, on=['DAYHOUR'])
df.drop(columns=['DAYHOUR'])
# Out:
#         DAYOFSERVICE   TRIPID LINEID ROUTEID  DIRECTION  PROGRNUMBER  \
# 0         2018-01-01  5955277     16   16_20          1           26
# 1         2018-01-01  5955277     16   16_20          1           28
# 2         2018-01-01  5955277     16   16_20          1           29
# 3         2018-01-01  5955277     16   16_20          1           30
# 4         2018-01-01  5955277     16   16_20          1           31
# ...              ...      ...    ...     ...        ...          ...
# 7158332   2018-12-31  8590615    65B  65B_65          1            8
# 7158333   2018-12-31  8590615    65B  65B_65          1            9
# 7158334   2018-12-31  8590615    65B  65B_65          1           10
# 7158335   2018-12-31  8590615    65B  65B_65          1           11
# 7158336   2018-12-31  8590615    65B  65B_65          1            6
#
#          startStop  ARR/DEP_PLAN  ARR_ACT  DEP_ACT  endStop  JOURNEYTIME  \
# 0               44         31277    31102    31102   7603.0         16.0
# 1               45         31343    31152    31163     46.0         55.0
# 2               46         31407    31207    31239     47.0         74.0
# 3               47         31484    31281    31288     48.0         34.0
# 4               48         31551    31315    31327     49.0         47.0
# ...            ...           ...      ...      ...      ...          ...
# 7158332       1017         21510    21435    21435   1018.0         16.0
# 7158333       1018         21540    21451    21451   1019.0         10.0
# 7158334       1019         21551    21461    21461   1020.0         12.0
# 7158335       1020         21564    21473    21473   1076.0         18.0
# 7158336       1285         21406    21314    21314   1016.0         94.0
#
#          MONTH  WEEKDAY  HOUR  temp  humidity  wind_speed  precipitation_1h
# 0            1        0     8  4.05        87        6.69               0.0
# 1            1        0     8  4.05        87        6.69               0.0
# 2            1        0     8  4.05        87        6.69               0.0
# 3            1        0     8  4.05        87        6.69               0.0
# 4            1        0     8  4.05        87        6.69               0.0
# ...        ...      ...   ...   ...       ...         ...               ...
# 7158332     12        0     5  8.86        81        3.10               0.0
# 7158333     12        0     5  8.86        81        3.10               0.0
# 7158334     12        0     5  8.86        81        3.10               0.0
# 7158335     12        0     5  8.86        81        3.10               0.0
# 7158336     12        0     5  8.86        81        3.10               0.0
#
# [7158337 rows x 19 columns]

# %%
df = df[['LINEID', 'DIRECTION', 'MONTH', 'WEEKDAY', 'HOUR', 'startStop', 'endStop', 'ARR_ACT', 'DEP_ACT',\
         'JOURNEYTIME', 'temp', 'humidity', 'wind_speed', 'precipitation_1h']]

# %%
df
# Out:
#         LINEID  DIRECTION  MONTH  WEEKDAY  HOUR  startStop  endStop  ARR_ACT  \
# 0           16          1      1        0     8         44   7603.0    31102
# 1           16          1      1        0     8         45     46.0    31152
# 2           16          1      1        0     8         46     47.0    31207
# 3           16          1      1        0     8         47     48.0    31281
# 4           16          1      1        0     8         48     49.0    31315
# ...        ...        ...    ...      ...   ...        ...      ...      ...
# 7158332    65B          1     12        0     5       1017   1018.0    21435
# 7158333    65B          1     12        0     5       1018   1019.0    21451
# 7158334    65B          1     12        0     5       1019   1020.0    21461
# 7158335    65B          1     12        0     5       1020   1076.0    21473
# 7158336    65B          1     12        0     5       1285   1016.0    21314
#
#          DEP_ACT  JOURNEYTIME  temp  humidity  wind_speed  precipitation_1h
# 0          31102         16.0  4.05        87        6.69               0.0
# 1          31163         55.0  4.05        87        6.69               0.0
# 2          31239         74.0  4.05        87        6.69               0.0
# 3          31288         34.0  4.05        87        6.69               0.0
# 4          31327         47.0  4.05        87        6.69               0.0
# ...          ...          ...   ...       ...         ...               ...
# 7158332    21435         16.0  8.86        81        3.10               0.0
# 7158333    21451         10.0  8.86        81        3.10               0.0
# 7158334    21461         12.0  8.86        81        3.10               0.0
# 7158335    21473         18.0  8.86        81        3.10               0.0
# 7158336    21314         94.0  8.86        81        3.10               0.0
#
# [7158337 rows x 14 columns]

# %% [markdown]
# ## Save df as csv file

# %%
df.to_csv(f'STOPS_MODELING_1.csv', index_label=False)

# %%
sorted(list(df['startStop'].unique()))
# Out:
# [14,
#  15,
#  17,
#  18,
#  19,
#  44,
#  45,
#  46,
#  47,
#  48,
#  49,
#  51,
#  495,
#  496,
#  515,
#  516,
#  519,
#  521,
#  522,
#  614,
#  615,
#  616,
#  617,
#  618,
#  619,
#  664,
#  665,
#  666,
#  667,
#  668,
#  672,
#  1016,
#  1017,
#  1018,
#  1019,
#  1020,
#  1069,
#  1070,
#  1071,
#  1285,
#  1443,
#  1444,
#  1476,
#  1478,
#  1479,
#  4384,
#  4528,
#  7453,
#  7603,
#  7659]
